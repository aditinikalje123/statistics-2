# %% [markdown]
# THEORY QUESTIONS
#
# 1)What is a random variable in probability theory
# Ans:-A random variable is a variable whose value is determined by the outcome of a random process.
#
#
# 2)What are the types of random variables
# Ans:-discrete random variable and continous random variable
#
# 3) What is the difference between discrete and continuous distributions
# Ans:-The difference between discrete(countable) and continuous(uncountable) distributions lies in the type of values their random variables can take and how probabilities are assigned.
#
# 4)What are probability distribution functions (PDF)
# Ans:-In probability theory, a Probability Distribution Function (PDF) refers to a function that describes the likelihood of a random variable taking on a particular value or range of values.
#
# 5)How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)
# Ans:-A Cumulative Distribution Function (CDF) gives the probability that a random variable is less than or equal to a certain value, while a Probability Distribution Function (PDF) (for continuous variables) or Probability Mass Function (PMF) (for discrete variables) describes the likelihood of specific values. The PDF shows how dense the probabilities are around a value, but the CDF accumulates those probabilities up to a point. For example, while a PDF tells you how likely a value is, the CDF tells you how likely it is to get a value up to that point. CDFs always increase from 0 to 1.
#
# 6) What is a discrete uniform distribution
# Ans:-A discrete uniform distribution is a probability distribution where all outcomes in a finite set are equally likely
#
# 7)What are the key properties of a Bernoulli distribution
# Ans:-takes two possible outcomes possiblely success and failure.
#
# 8)What is the binomial distribution, and how is it used in probability
# Ans:-The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes: success or failure.
#
# 9) What is the Poisson distribution and where is it applied
# Ans:-The Poisson distribution is a discrete probability distribution that models the number of times an event occurs in a fixed interval of time or space, given a constant average rate and independence between events.
#
# 10)What is a continuous uniform distribution
# Ans:-A continuous uniform distribution is a probability distribution where a continuous random variable takes values equally likely within a specific interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b]
#
# 11)What are the characteristics of a normal distribution
# Ans:-bell shaped, symmetric , mean/median/mode are equal ,68-95-99.7
#
# 12)What is the standard normal distribution, and why is it important
# Ans:-The standard normal distribution is a special case of the normal distribution with a mean (
# 𝜇
# μ) of 0 and a standard deviation (
# 𝜎
# σ) of 1.
#
# 13)What is the Central Limit Theorem (CLT), and why is it critical in statistics
# Ans:-When you take a sufficiently large number of independent, random samples from any population (regardless of its distribution), the distribution of the sample means will approximate a normal distribution — with mean equal to the population mean and variance equal to the population variance divided by the sample size.
#
# 14) How does the Central Limit Theorem relate to the normal distribution
# Ans:-The Central Limit Theorem (CLT) explains why the normal distribution appears so often in statistics: it states that the distribution of the sample means of a large number of independent, identically distributed random variables will be approximately normal, regardless of the original population’s distribution.
#
#
#
# 15)What is the application of Z statistics in hypothesis testing
# Ans:-Z-statistics (or Z-tests) are widely used in hypothesis testing when you want to determine whether a sample mean significantly differs from a known population mean, especially when the population standard deviation is known or the sample size is large.
#
# 16)How do you calculate a Z-score, and what does it represent
# Ans:-The Z-score of a value
# The Z-score tells you how many standard deviations a value
# 𝑥
# x is above or below the mean.
#
# A positive Z-score means
# 𝑥
# x is above the mean.
#
# A negative Z-score means
# 𝑥
# x is below the mean.
#
# A Z-score of 0 means the value is exactly at the mean.
#
# 17)What are point estimates and interval estimates in statistics
# Ans:-A point estimate is a single value calculated from sample data that serves as the best guess or estimate of an unknown population parameter (like the mean or proportion).
# An interval estimate provides a range of values within which the population parameter is likely to lie, along with a confidence level.
#
# 18)What is the significance of confidence intervals in statistical analysis
# Ans:-Confidence intervals (CIs) are crucial in statistics because they provide a range of plausible values for an unknown population parameter, rather than just a single point estimate. This helps quantify the uncertainty inherent in sampling.
#
# 19)What is the relationship between a Z-score and a confidence interval
# Ans:-The Z-score and confidence interval (CI) are closely connected because the Z-score helps determine the width of the confidence interval when estimating a population parameter.
#
# 20)How are Z-scores used to compare different distributions
# Ans:-Z-scores allow you to standardize values from different distributions so you can compare them on the same scale, even if the original data have different means and standard deviations.
#
# 21)What are the assumptions for applying the Central Limit Theorem
# Ans:-Independence:
# The sampled observations must be independent of each other. This is usually ensured by random sampling or random assignment.
#
# Sample Size:
# The sample size
# 𝑛
# n should be sufficiently large. While there’s no strict cutoff,
# 𝑛
# ≥
# 30
# n≥30 is a common rule of thumb for many distributions. For populations already close to normal, smaller samples may suffice.
#
# Identically Distributed:
# The samples are drawn from the same population with the same distribution.
#
# Finite Variance:
# The population must have a finite variance (i.e., variability isn’t infinite).
#
# 22) What is the concept of expected value in a probability distribution
# Ans:-The expected value of a probability distribution is essentially the long-run average or mean value you would expect if you repeated an experiment many times.
#
# 23)How does a probability distribution relate to the expected outcome of a random variable
# Ans:-A probability distribution describes all possible outcomes of a random variable and the probabilities associated with each outcome. The expected outcome (or expected value) is a summary measure derived from that distribution.
